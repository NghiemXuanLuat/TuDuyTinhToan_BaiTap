# %% [markdown]
# W6A1
# Nhập vào một dòng gồm các số nguyên. Hãy loại bỏ phần tử trùng nhưng
# giữ nguyên thứ tự xuất hiện đầu tiên, rồi in ra list kết quả.
# Yêu cầu in ra đúng dạng list Python, ví dụ [1, 2, 3]

# %%
a = list(map(int, input().split()))
da_thay = set()
ket = []
for i in a:
    if i not in da_thay:
        ket.append(i)
        da_thay.add(i)
print(ket)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a = list(map(int, input().split()))
#       2 da_thay = set()
#       3 ket = []
#
# ValueError: invalid literal for int() with base 10: 'h'

# %%
a = list(map(int, input().split()))
b = []
for i in range(len(a)):
    if a[i] not in b:
        b.append(a[i])

print(b)
print(a)
# Out:
# [1, 2, 3, 4]
# [1, 2, 2, 3, 1, 4]

# %% [markdown]
# W6A2
# Nhập một dòng số nguyên. In ra list tổng tích lũy (phần tử i là tổng từ đầu
# tới vị trí i), giữ nguyên thứ tự

# %%
a = list(map(int, input().split()))
b = [sum(a[:i + 1]) for i in range(len(a))]
print(b)
# Out:
# [2, 5, 9, 14, 20]

# %%
a = list(map(int, input().split()))
def ham(a):
    F = [None]*len(a)
    F[0] = a[0]
    for i in range(1,len(a)):
        F[i] = F[i-1] + a[i]
    return F

print(ham(a))
# Out:
# [10, 5, 15]

# %% [markdown]
# W6A3
# Nhập một tuple số nguyên (một dòng) và số nguyên k (dòng kế). In ra tuple
# sau khi xoay trái k vị trí. (Giữ nguyên thứ tự tương đối sau xoay; không sắp xep

# %%
a = list(map(int, input().split()))
k = int(input())
k = k % len(a)
b = a[k:] + a[:k]
print(b)
# Out:
# [3, 4, 5, 1, 2]

# %%
a = tuple(map(int, input().split()))
k = int(input())
a = list(a)
b = [None]*len(a)
for i in range(len(a)):
    b[i-k] = a[i]
print(tuple(b))
# Out:
# (3, 4, 5, 1, 2)

# %% [markdown]
# W6A4
# Nhập một dòng gồm các cặp key:value cách nhau bởi dấu cách. Tạo
# dictionary ánh xạ mỗi key -> list các value theo thứ tự xuất hiện. Nếu key lặp
# lại, thêm vào list của key đó

# %%
a = input().split()
b = {}
for i in a:
    k,v = i.split(':')
    b.setdefault(k, []).append(int(v))
print(b)
# Out:
# {'a': [1, 8], 'b': [2], 'c': [6]}

# %%
a = input().split()
b = {}
for i in a:
    key, value = i.split(':')
    if key not in b:
        b[key] = [value]
    else:
        b[key].append(value)
print(b)
# Out:
# {'a': ['1', '3'], 'b': ['2']}

# %% [markdown]
# W6A5
# Nhập một list số nguyên, In ra dictionary {'positives': ..., 'negatives': ..., 'zeros':
# ...} (đếm số >0, <0, =0)

# %%
a = list(map(int, input().split()))
b = {'duong' : 0, 'am' : 0, 'khong' : 0}
for i in a:
    if i > 0:
        b['duong'] += 1
    elif i < 0:
       b['am'] += 1
    else:
        b['khong'] += 1
print(b)
# Out:
# {'duong': 5, 'am': 3, 'khong': 3}

# %%
a = list(map(int, input().split()))
du = 0
am = 0
kh = 0
for i in a:
    if i > 0:
        du += 1
    elif i < 0:
        am += 1
    else:
        kh += 1
        
b = { 'positives': du, 'negatives' : am, 'zero':kh}
print(b)
# Out:
# {'positives': 2, 'negatives': 2, 'zero': 3}

# %% [markdown]
#  W6A6
# Viết chương trình nhập vào một danh sách các số nguyên, sau đó in ra tổng các số
# trong list đó.

# %%
a = list(map(int, input().split()))
print(sum(a))
# Out:
# 10

# %% [markdown]
#  W6A7
# Viết chương trình nhập vào một tuple, in ra phần tử đầu, phần tử cuối, và tuple đảo
# ngược

# %%
a = list(map(str, input().split()))
b = tuple(a[::-1])
print(a[0], a[-1], b, sep = '\n')
# Out:
# 1
# 3
# ('3', '2', '1')

# %% [markdown]
# W6A8
# Viết chương trình nhập vào một list các chuỗi, sau đó đếm số lần xuất hiện của từng
# chuỗi và lưu vào dictionary

# %%
from collections import Counter
a = list(map(int, input().split()))
b = Counter(a)
print(b)
# Out:
# Counter({1: 2, 2: 2, 3: 1, 4: 1, 6: 1, 7: 1})

# %%
a = input().split()
b = {}
for i in a:
    if i not in b:
        b[i] = 1
    else:
        b[i] += 1
print(b)
# Out:
# {'cat': 2, 'mouse': 1}

# %% [markdown]
# W6A9
# Viết chương trình nhập vào hai dictionary. Sau đó gộp lại thành một dictionary mới
# trong đó nếu một key xuất hiện trong cả hai dict, giá trị sẽ được cộng lại, nếu chỉ có
# trong một dict thì giữ nguyên. In ra dictionary mới theo thứ tự từ điển tăng dần của
# key.

# %%
d1 = eval(input())
d2 = eval(input())
for k, v in d2.items():
    d1[k] = d1.get(k, 0) + v
b = dict(sorted(d1.items()))
print(b)
# Out:
# {'a': 2, 'b': 12, 'c': 6}

# %%
d1 = eval(input())
d2 = eval(input())
for key, value in d2.items():
    if key in d1:
        d1[key] += value
    else:
        d1[key] = value
a = sorted(d1.items())
c = dict(a)
print(c)
# Out:
# {'a': 1, 'b': 6, 'c': 3}

# %% [markdown]
# W6A10
# Viết chương trình nhập vào một danh sách các số nguyên, và số nguyên dương k. In ra
# list gồm các cặp số khác nhau có tổng bằng k. Mỗi cặp là một tuple, hai số trong tuple
# có thể giống nhau, thứ tự xuất hiện trong danh sách của số thứ nhất nhỏ hơn thứ tự của
# số thứ hai. Các tuple trong list được sắp xếp theo thứ tự tăng dần của phần tử đầu tiên
# trong tuple.

# %%
a = list(map(int, input().split()))
k = int(input())
gio = set()
ket = set()
for i in a:
    can_tim = k - i
    if can_tim in gio:
        ket.add((i, can_tim))
    gio.add(i)
b = sorted(list(ket))
print(b)
# Out:
# [(4, 2), (5, 1)]

# %%
a = list(map(int, input().split()))
k = int(input())
b =set()
n = len(a)
for i in range(n):
    for j in range(i+1,n):
        if a[i] + a[j] == k:
            b.add((a[i], a[j]))
c = sorted(list(b), key = lambda x : x[0])
print(c)
# Out:
# [(1, 5), (2, 4), (3, 3)]

# %%
a = list(map(int, input()))
gio = set()

# %% [markdown]
# W6A11
# [Tách số chẵn và lẻ từ tuple]
# Nhập vào một tuple chứa các số nguyên. Hãy tạo ra hai tuple mới: một chứa
# tất cả các số chẵn và một chứa tất cả các số lẻ từ tuple ban đầu, giữ nguyên
# thứ tự tương đối. In ra hai tuple này trên hai dòng riêng biệt.

# %%
a = list(map(int, input().split()))
b = [k for k in a if k%2 == 0]
c = [k for k in a if k % 2 != 0]
print(b)
print(c)
# Out:
# [2, 4, 6, 8, 0]
# [1, 3, 5, 7, 9]

# %%
a = list(map(int, input().split()))
chan = []
le = []
for i in a:
    if i % 2 == 0:
        chan.append(i)
    else:
        le.append(i)
print(tuple(chan))
print(tuple(le))
# Out:
# (10, 2, 8, 4, 6)
# (1, 9, 3, 7, 5)

# %% [markdown]
# 12
# [Tìm phần tử xuất hiện nhiều nhất]
# Nhập vào một list các số nguyên. Hãy tìm số xuất hiện nhiều lần nhất trong list.
# Nếu có nhiều số cùng có số lần xuất hiện nhiều nhất, hãy in ra số nhỏ nhất
# trong số đó.

# %%
a = list(map(int, input().split()))
b = {v:a.count(v) for v in a}
c = max(b, key = lambda x : (b[x], -x))
print(c)

# %%
a = list(map(int, input().split()))
b = {v:a.count(v) for i,v in enumerate(a)}
c = max(b, key = lambda x: (b[x], -x))
print(c)
# Out:
# 3

# %%
a = list(map(int, input().split()))
b = {}
for i in a:
    if i not in b:
        b[i] = 1
    else:
        b[i] += 1
        
c = 0
d = None
for i in b.keys():
    if b[i] > c:
        c = b[i]
        d = i
    elif b[i] == c:
        if int(i) < int(d):
            d = i
            
print(d)
# Out:
# -3

# %%
from collections import Counter 
a = list(map(int, input().split()))
dem = Counter(a)
ket = max(dem, key = lambda x: (dem[x], -x))
print(ket)
# Out:
# 1

# %% [markdown]
# W6A13
# [Đảo ngược key và value của dictionary]
# Nhập vào một dictionary có value là duy nhất (không trùng nhau). Hãy tạo một
# dictionary mới bằng cách đảo ngược key và value của dictionary ban đầu. In
# ra dictionary mới.

# %%
a = iter(input().split())
b = dict(zip(a,a))
c = {k:v for v,k in b.items()}
print(c)
# Out:
# {'1': 'a', '2': 'b', '3': 'c'}

# %%
a = input().split()
a = list(a)
key = []
value = []
for i in range(len(a)):
    if i % 2 == 0:
        key.append(a[i])
    else:
        value.append(a[i])
        
b = dict(zip(value, key))
print(b)
# Out:
# {'1': 'a', '2': 'b', '3': 'c'}

# %%
a = iter(input().split())
b = dict(zip(a,a))
c = {v:k for k,v in b.items()}
print(c)
# Out:
# {'1': 'a', '2': 'b', '3': 'c'}

# %% [markdown]
# W6A14
# [Giao của hai danh sách]
# Nhập vào hai dòng, mỗi dòng là một danh sách các số nguyên. Hãy tìm các
# phần tử chung (giao) của hai danh sách này và in ra một list mới chứa các
# phần tử chung đó, không trùng lặp.

# %%
a = list(map(int, input().split()))
b = list(map(int, input().split()))
c = []
for i in a:
    if (i in b) and (i not in c):
        c.append(i)
print(c)
# Out:
# [4, 4, 5]

# %%
a = list(map(int, input().split()))
b = list(map(int, input().split()))
c = [i for i in dict.fromkeys(a) if i in s]

# %%
a = list(map(int, input().split()))
b = list(map(int, input().split()))
c = []
for i in a:
    if i in b and i not in c:
        c.append(i)
print(c)
# Out:
# [4, 5]

# %% [markdown]
# W6A15
# [Lọc dictionary theo giá trị]
# Nhập vào một dictionary có key là chuỗi và value là số nguyên, và một số
# nguyên k ở dòng tiếp theo. Hãy tạo một dictionary mới chỉ chứa các cặp keyvalue từ dictionary ban đầu mà có value lớn hơn k. In ra dictionary mới.

# %%
a = iter(input().split())
d = int(input())
b = dict(zip(a,a))
c = {k: int(v) for k,v in b.items() if  int(v) > d}
print(c)
# Out:
# {'math': 95, 'english': 92}

# %%
a = list(input().split())
k = int(input())
b = []
c = []
d = {}
for i in range(len(a)):
    if i % 2 == 0:
        b.append(a[i])
    else:
        c.append(a[i])
        
c = [ int(x) for x in c]
for i in range(len(b)):
    if  c[i]> k:
        d[b[i]] = c[i]
        
print(d)
# Out:
# {'c': 3}

# %%
a = iter(input().split())
m = int(input())
c = dict(zip(a,a))
b = {k: int(v) for k,v in c.items() if int(v) > m}
print(b)
# Out:
# {'apple': 10, 'banana': 20, 'orange': 15}
